# %%
import sys
import json

# %%
sys.version_info[0]
# Out:
# 3

# %%
import ast

# %%
    with open('stations.json') as f:
        stationlist = json.load(f)

# %%
stationlist
# Out:
# [[282865093,
#   {'aerialway': 'station', 'name': 'Lorenzi'},
#   [12.0097179, 46.7449889]],
#  [282865094,
#   {'aerialway': 'station', 'name': 'Lorenzi'},
#   [11.9901255, 46.7433392]],
#  [283551172,
#   {'aerialway': 'station', 'name': 'Sonne'},
#   [11.9584703, 46.7379001]],
#  [283551174,
#   {'aerialway': 'station', 'name': 'Sonne'},
#   [11.9615861, 46.73208]],
#  [283553882,
#   {'aerialway': 'station',
#    'name': 'Olang I - Valdaora I',
#    'name:de': 'Olang I',
#    'name:it': 'Valdaora I'},
#   [12.0105322, 46.7466875]],
#  [283553888,
#   {'aerialway': 'station',
#    'aerialway:access': 'both',
#    'aerialway:summer:access': 'both',
#    'name': 'Olang I / II'},
#   [11.9726018, 46.743553]],
#  [283553892,
#   {'aerialway': 'station',
#    'aerialway:access': 'both',
#    'aerialway:summer:access': 'both',
#    'name': 'Olang II'},
#   [11.9596764, 46.7393443]],
#  [283553894,
#   {'aerialway': 'station', 'ele:local': '1662', 'name': 'Arndt'},
# ...
